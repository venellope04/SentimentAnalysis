# %% [markdown]
# # **TASK-1**
# **Sentiment Analysis:** Analyze social media or product reviews to determine sentiment (positive, negative, neutral).

# %% [markdown]
# -->Sentiment analysis is a process that analyzes written or spoken language to determine if the tone is positive, negative, or neutral. It's a type of text analysis that uses natural language processing (NLP) to assign a score to each clause based on the sentiment expressed in the text.
#
# Here we analyzed customer sentiment in Amazon product reviews

# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, accuracy_score
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# **1. Load and Inpect the Dataset**

# %%
# Load the dataset
data = pd.read_csv("/content/sample_data/EMS2.csv", encoding='latin-1')
data
# Out:
#                                                  link  \
# 0   https://www.google.com/maps/reviews/data=!4m8!...
# 1   https://www.google.com/maps/reviews/data=!4m8!...
# 2   https://www.google.com/maps/reviews/data=!4m8!...
# 3   https://www.google.com/maps/reviews/data=!4m8!...
# 4   https://www.google.com/maps/reviews/data=!4m8!...
# ..                                                ...
# 89  <iframe src="https://www.facebook.com/plugins/...
# 90  <iframe src="https://www.facebook.com/plugins/...
# 91  https://www.justdial.com/Pune/Sparse-Matrix-So...
# 92  https://www.justdial.com/Pune/Sparse-Matrix-So...
# 93  https://www.justdial.com/Pune/Sparse-Matrix-So...
#
#                                                Review  \
# 0   Here I joined as an intern.I have learned lots...
# 1   Being a part of eSparse Matrix Solution pvt lt...
# 2   Team of dedicated, talented and experienced pr...
# 3   Here I joined as an intern. I have learned lot...
# 4   Here I joined as an intern . here team leaders...
# ..                                                ...
# 89  fantastic team. They gove had a long time to c...
# 90  Best Software Development Company with Best Se...
# 91  Sparse Matrix Solutions is great work place, m...
# 92   I have been working at Best Companies full-time.
# 93  Great organizational culture and highly techni...
#
#                                        date    source  \
# 0                                a year ago    Google
# 1                               3 years ago    Google
# 2                               2 years ago    Google
# 3                               3 years ago    Google
# 4                               3 years ago    Google
# ..                                      ...       ...
# 89        Monday, June 19, 2023 at 11:08 AM  Facebook
# 90  Thursday, November 18, 2021 at 10:47 AM  Facebook
# 91                     Thursday, 10/24/2019  Justdial
# 92                     Thursday, 10/24/2019  Justdial
# 93                       Friday, 10/25/2019  Justdial
#
#                                                  user
# 0   {\n  "name": "KALSE PRATHMESH PRASHANT",\n  "l...
# 1   {\n  "name": "Prashansha Jadon",\n  "link": "h...
# 2   {\n  "name": "Sohail Daudani",\n  "link": "htt...
# 3   {\n  "name": "Pallabi Devi",\n  "link": "https...
# 4   {\n  "name": "Dhage Vaishnavi",\n  "link": "ht...
# ..                                                ...
# 89                          PROMINENT PUBLICATION LLP
# 90                                    Swami Raj Villa
# 91                                            KRISHNA
# 92                                              Onkar
# 93                                     Rahul Paatil\n
#
# [94 rows x 5 columns]

# %%
# View basic details
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   link    94 non-null     object
#  1   Review  72 non-null     object
#  2   date    94 non-null     object
#  3   source  94 non-null     object
#  4   user    94 non-null     object
# dtypes: object(5)
# memory usage: 3.8+ KB

# %% [markdown]
# **Step 2: Preprocess the Data**
#
# Clean the column

# %%
# Text cleaning function
def clean_text(text):
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\d+', '', text)      # Remove numbers
    text = text.lower()                  # Convert to lowercase
    return text

# Apply cleaning
data['cleaned_review_summary'] = data['Review'].apply(lambda x: clean_text(str(x)))

# Check for missing values and drop them if necessary
#data.dropna(subset=['cleaned_review_summary','Review' ], inplace=True)
data
# Out:
#                                                  link  \
# 0   https://www.google.com/maps/reviews/data=!4m8!...
# 1   https://www.google.com/maps/reviews/data=!4m8!...
# 2   https://www.google.com/maps/reviews/data=!4m8!...
# 3   https://www.google.com/maps/reviews/data=!4m8!...
# 4   https://www.google.com/maps/reviews/data=!4m8!...
# ..                                                ...
# 89  <iframe src="https://www.facebook.com/plugins/...
# 90  <iframe src="https://www.facebook.com/plugins/...
# 91  https://www.justdial.com/Pune/Sparse-Matrix-So...
# 92  https://www.justdial.com/Pune/Sparse-Matrix-So...
# 93  https://www.justdial.com/Pune/Sparse-Matrix-So...
#
#                                                Review  \
# 0   Here I joined as an intern.I have learned lots...
# 1   Being a part of eSparse Matrix Solution pvt lt...
# 2   Team of dedicated, talented and experienced pr...
# 3   Here I joined as an intern. I have learned lot...
# 4   Here I joined as an intern . here team leaders...
# ..                                                ...
# 89  fantastic team. They gove had a long time to c...
# 90  Best Software Development Company with Best Se...
# 91  Sparse Matrix Solutions is great work place, m...
# 92   I have been working at Best Companies full-time.
# 93  Great organizational culture and highly techni...
#
#                                        date    source  \
# 0                                a year ago    Google
# 1                               3 years ago    Google
# 2                               2 years ago    Google
# 3                               3 years ago    Google
# 4                               3 years ago    Google
# ..                                      ...       ...
# 89        Monday, June 19, 2023 at 11:08 AM  Facebook
# 90  Thursday, November 18, 2021 at 10:47 AM  Facebook
# 91                     Thursday, 10/24/2019  Justdial
# 92                     Thursday, 10/24/2019  Justdial
# 93                       Friday, 10/25/2019  Justdial
#
#                                                  user  \
# 0   {\n  "name": "KALSE PRATHMESH PRASHANT",\n  "l...
# 1   {\n  "name": "Prashansha Jadon",\n  "link": "h...
# 2   {\n  "name": "Sohail Daudani",\n  "link": "htt...
# 3   {\n  "name": "Pallabi Devi",\n  "link": "https...
# 4   {\n  "name": "Dhage Vaishnavi",\n  "link": "ht...
# ..                                                ...
# 89                          PROMINENT PUBLICATION LLP
# 90                                    Swami Raj Villa
# 91                                            KRISHNA
# 92                                              Onkar
# 93                                     Rahul Paatil\n
#
#                                cleaned_review_summary
# 0   here i joined as an interni have learned lots ...
# 1   being a part of esparse matrix solution pvt lt...
# 2   team of dedicated talented and experienced pro...
# 3   here i joined as an intern i have learned lots...
# 4   here i joined as an intern  here team leaders ...
# ..                                                ...
# 89  fantastic team they gove had a long time to co...
# 90  best software development company with best se...
# 91  sparse matrix solutions is great work place ma...
# 92     i have been working at best companies fulltime
# 93  great organizational culture and highly techni...
#
# [94 rows x 6 columns]

# %% [markdown]
# Formating Date to have it in same format

# %%
from datetime import datetime, timedelta


# Define a function to clean and standardize the date format
def clean_date(date):
    try:
        # Check if the date is a relative format like "3 years ago"
        if "years ago" in date:
            years_ago = int(date.split()[0])
            return (datetime.now() - timedelta(days=years_ago*365)).strftime('%Y-%m-%d')
        elif "months ago" in date:
            months_ago = int(date.split()[0])
            return (datetime.now() - timedelta(days=months_ago*30)).strftime('%Y-%m-%d')
        elif "days ago" in date:
            days_ago = int(date.split()[0])
            return (datetime.now() - timedelta(days=days_ago)).strftime('%Y-%m-%d')
        else:
            # Convert to datetime object and standardize the format
            return pd.to_datetime(date).strftime('%Y-%m-%d')
    except Exception as e:
        print(f"Error parsing date: {date}, {e}")
        return None

# Apply the cleaning function to the 'date' column
data['cleaned_date'] = data['date'].apply(clean_date)

# Drop rows where date conversion failed
data.dropna(subset=['cleaned_date'], inplace=True)

# Optionally, replace the old date column with the cleaned one
data['date'] = data['cleaned_date']
data.drop(columns=['cleaned_date'], inplace=True)


data
# Out:
# Error parsing date: a year ago, Unknown datetime string format, unable to parse: a year ago, at position 0
# Error parsing date: a year ago, Unknown datetime string format, unable to parse: a year ago, at position 0
# Error parsing date: a year ago, Unknown datetime string format, unable to parse: a year ago, at position 0
#                                                  link  \
# 1   https://www.google.com/maps/reviews/data=!4m8!...
# 2   https://www.google.com/maps/reviews/data=!4m8!...
# 3   https://www.google.com/maps/reviews/data=!4m8!...
# 4   https://www.google.com/maps/reviews/data=!4m8!...
# 5   https://www.google.com/maps/reviews/data=!4m8!...
# ..                                                ...
# 89  <iframe src="https://www.facebook.com/plugins/...
# 90  <iframe src="https://www.facebook.com/plugins/...
# 91  https://www.justdial.com/Pune/Sparse-Matrix-So...
# 92  https://www.justdial.com/Pune/Sparse-Matrix-So...
# 93  https://www.justdial.com/Pune/Sparse-Matrix-So...
#
#                                                Review        date    source  \
# 1   Being a part of eSparse Matrix Solution pvt lt...  2021-12-07    Google
# 2   Team of dedicated, talented and experienced pr...  2022-12-07    Google
# 3   Here I joined as an intern. I have learned lot...  2021-12-07    Google
# 4   Here I joined as an intern . here team leaders...  2021-12-07    Google
# 5   I had worked for 3 months with esparse matrix ...  2021-12-07    Google
# ..                                                ...         ...       ...
# 89  fantastic team. They gove had a long time to c...  2023-06-19  Facebook
# 90  Best Software Development Company with Best Se...  2021-11-18  Facebook
# 91  Sparse Matrix Solutions is great work place, m...  2019-10-24  Justdial
# 92   I have been working at Best Companies full-time.  2019-10-24  Justdial
# 93  Great organizational culture and highly techni...  2019-10-25  Justdial
#
#                                                  user  \
# 1   {\n  "name": "Prashansha Jadon",\n  "link": "h...
# 2   {\n  "name": "Sohail Daudani",\n  "link": "htt...
# 3   {\n  "name": "Pallabi Devi",\n  "link": "https...
# 4   {\n  "name": "Dhage Vaishnavi",\n  "link": "ht...
# 5   {\n  "name": "Binny Chouhan",\n  "link": "http...
# ..                                                ...
# 89                          PROMINENT PUBLICATION LLP
# 90                                    Swami Raj Villa
# 91                                            KRISHNA
# 92                                              Onkar
# 93                                     Rahul Paatil\n
#
#                                cleaned_review_summary
# 1   being a part of esparse matrix solution pvt lt...
# 2   team of dedicated talented and experienced pro...
# 3   here i joined as an intern i have learned lots...
# 4   here i joined as an intern  here team leaders ...
# 5   i had worked for  months with esparse matrix s...
# ..                                                ...
# 89  fantastic team they gove had a long time to co...
# 90  best software development company with best se...
# 91  sparse matrix solutions is great work place ma...
# 92     i have been working at best companies fulltime
# 93  great organizational culture and highly techni...
#
# [91 rows x 6 columns]

# %% [markdown]
# **3. Initialize VADER Sentiment Analyzer**

# %%
# Initialize SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %% [markdown]
# **4. Analyze Sentiment of Review**
# Use VADER to assign a sentiment score to each review.

# %%
# Function to get sentiment from VADER
def analyze_sentiment(text):
    score = sia.polarity_scores(str(text))  # Get sentiment scores
    if score['compound'] > 0.05:
        return 'positive'
    elif score['compound'] < -0.05:
        return 'negative'
    else:
        return 'neutral'

# Apply the sentiment analysis
data['predicted_sentiment'] = data['Review'].apply(analyze_sentiment)

# Display results
data[['Review', 'predicted_sentiment']]
# Out:
#                                                Review predicted_sentiment
# 1   Being a part of eSparse Matrix Solution pvt lt...            positive
# 2   Team of dedicated, talented and experienced pr...            positive
# 3   Here I joined as an intern. I have learned lot...            positive
# 4   Here I joined as an intern . here team leaders...            positive
# 5   I had worked for 3 months with esparse matrix ...            positive
# ..                                                ...                 ...
# 89  fantastic team. They gove had a long time to c...            positive
# 90  Best Software Development Company with Best Se...            positive
# 91  Sparse Matrix Solutions is great work place, m...            positive
# 92   I have been working at Best Companies full-time.            positive
# 93  Great organizational culture and highly techni...            positive
#
# [91 rows x 2 columns]

# %% [markdown]
# **6. Removing Negative Reviews**

# %%
# Filter out negative reviews
data = data[(data['predicted_sentiment'] != 'negative')]
data
# Save filtered dataset
#data.to_csv("filtered_reviews.csv", index=False)
# Out:
#                                                  link  \
# 1   https://www.google.com/maps/reviews/data=!4m8!...
# 2   https://www.google.com/maps/reviews/data=!4m8!...
# 3   https://www.google.com/maps/reviews/data=!4m8!...
# 4   https://www.google.com/maps/reviews/data=!4m8!...
# 5   https://www.google.com/maps/reviews/data=!4m8!...
# ..                                                ...
# 89  <iframe src="https://www.facebook.com/plugins/...
# 90  <iframe src="https://www.facebook.com/plugins/...
# 91  https://www.justdial.com/Pune/Sparse-Matrix-So...
# 92  https://www.justdial.com/Pune/Sparse-Matrix-So...
# 93  https://www.justdial.com/Pune/Sparse-Matrix-So...
#
#                                                Review        date    source  \
# 1   Being a part of eSparse Matrix Solution pvt lt...  2021-12-07    Google
# 2   Team of dedicated, talented and experienced pr...  2022-12-07    Google
# 3   Here I joined as an intern. I have learned lot...  2021-12-07    Google
# 4   Here I joined as an intern . here team leaders...  2021-12-07    Google
# 5   I had worked for 3 months with esparse matrix ...  2021-12-07    Google
# ..                                                ...         ...       ...
# 89  fantastic team. They gove had a long time to c...  2023-06-19  Facebook
# 90  Best Software Development Company with Best Se...  2021-11-18  Facebook
# 91  Sparse Matrix Solutions is great work place, m...  2019-10-24  Justdial
# 92   I have been working at Best Companies full-time.  2019-10-24  Justdial
# 93  Great organizational culture and highly techni...  2019-10-25  Justdial
#
#                                                  user  \
# 1   {\n  "name": "Prashansha Jadon",\n  "link": "h...
# 2   {\n  "name": "Sohail Daudani",\n  "link": "htt...
# 3   {\n  "name": "Pallabi Devi",\n  "link": "https...
# 4   {\n  "name": "Dhage Vaishnavi",\n  "link": "ht...
# 5   {\n  "name": "Binny Chouhan",\n  "link": "http...
# ..                                                ...
# 89                          PROMINENT PUBLICATION LLP
# 90                                    Swami Raj Villa
# 91                                            KRISHNA
# 92                                              Onkar
# 93                                     Rahul Paatil\n
#
#                                cleaned_review_summary predicted_sentiment
# 1   being a part of esparse matrix solution pvt lt...            positive
# 2   team of dedicated talented and experienced pro...            positive
# 3   here i joined as an intern i have learned lots...            positive
# 4   here i joined as an intern  here team leaders ...            positive
# 5   i had worked for  months with esparse matrix s...            positive
# ..                                                ...                 ...
# 89  fantastic team they gove had a long time to co...            positive
# 90  best software development company with best se...            positive
# 91  sparse matrix solutions is great work place ma...            positive
# 92     i have been working at best companies fulltime            positive
# 93  great organizational culture and highly techni...            positive
#
# [91 rows x 7 columns]

# %% [markdown]
# Segregrate and Display reviews from facebook and Google

# %%
FBreviews = data[data['source'] == 'Facebook']
FBreviews
# Out:
#                                                  link  \
# 87  <iframe src="https://www.facebook.com/plugins/...
# 88  <iframe src="https://www.facebook.com/plugins/...
# 89  <iframe src="https://www.facebook.com/plugins/...
# 90  <iframe src="https://www.facebook.com/plugins/...
#
#                                                Review        date    source  \
# 87  I Highly review Esparse Matrix Solutions for a...  2023-06-22  Facebook
# 88  Best Software Development company. They develo...  2023-06-19  Facebook
# 89  fantastic team. They gove had a long time to c...  2023-06-19  Facebook
# 90  Best Software Development Company with Best Se...  2021-11-18  Facebook
#
#                          user  \
# 87          Gernari Holidays
# 88          Diwanji Services
# 89  PROMINENT PUBLICATION LLP
# 90            Swami Raj Villa
#
#                                cleaned_review_summary predicted_sentiment
# 87  i highly review esparse matrix solutions for a...            positive
# 88  best software development company they develop...            positive
# 89  fantastic team they gove had a long time to co...            positive
# 90  best software development company with best se...            positive

# %%
GReviews = data[data['source'] == 'Google']
GReviews
# Out:
#                                                  link  \
# 1   https://www.google.com/maps/reviews/data=!4m8!...
# 2   https://www.google.com/maps/reviews/data=!4m8!...
# 3   https://www.google.com/maps/reviews/data=!4m8!...
# 4   https://www.google.com/maps/reviews/data=!4m8!...
# 5   https://www.google.com/maps/reviews/data=!4m8!...
# ..                                                ...
# 82  https://www.google.com/maps/reviews/data=!4m8!...
# 83  https://www.google.com/maps/reviews/data=!4m8!...
# 84  https://www.google.com/maps/reviews/data=!4m8!...
# 85  https://www.google.com/maps/reviews/data=!4m8!...
# 86  https://www.google.com/maps/reviews/data=!4m8!...
#
#                                                Review        date  source  \
# 1   Being a part of eSparse Matrix Solution pvt lt...  2021-12-07  Google
# 2   Team of dedicated, talented and experienced pr...  2022-12-07  Google
# 3   Here I joined as an intern. I have learned lot...  2021-12-07  Google
# 4   Here I joined as an intern . here team leaders...  2021-12-07  Google
# 5   I had worked for 3 months with esparse matrix ...  2021-12-07  Google
# ..                                                ...         ...     ...
# 82                                                NaN  2021-12-07  Google
# 83                                                NaN  2019-12-08  Google
# 84                                                NaN  2019-12-08  Google
# 85                                                NaN  2020-12-07  Google
# 86                                                NaN  2020-12-07  Google
#
#                                                  user  \
# 1   {\n  "name": "Prashansha Jadon",\n  "link": "h...
# 2   {\n  "name": "Sohail Daudani",\n  "link": "htt...
# 3   {\n  "name": "Pallabi Devi",\n  "link": "https...
# 4   {\n  "name": "Dhage Vaishnavi",\n  "link": "ht...
# 5   {\n  "name": "Binny Chouhan",\n  "link": "http...
# ..                                                ...
# 82  {\n  "name": "Pankaj Keshwani",\n  "link": "ht...
# 83  {\n  "name": "Amol Sirsat",\n  "link": "https:...
# 84  {\n  "name": "Rahul Chinchore",\n  "link": "ht...
# 85  {\n  "name": "pranav vadnere",\n  "link": "htt...
# 86  {\n  "name": "Rushikesh Jagtap (RJ)",\n  "link...
#
#                                cleaned_review_summary predicted_sentiment
# 1   being a part of esparse matrix solution pvt lt...            positive
# 2   team of dedicated talented and experienced pro...            positive
# 3   here i joined as an intern i have learned lots...            positive
# 4   here i joined as an intern  here team leaders ...            positive
# 5   i had worked for  months with esparse matrix s...            positive
# ..                                                ...                 ...
# 82                                                nan             neutral
# 83                                                nan             neutral
# 84                                                nan             neutral
# 85                                                nan             neutral
# 86                                                nan             neutral
#
# [84 rows x 7 columns]
